# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv('Netflix Subscription Fee.csv')

# %%
df.shape
# Out:
# (65, 8)

# %%
df.head()
# Out:
#   Country_code    Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0           ar  Argentina                4760             3154           1606
# 1           au  Australia                6114             4050           2064
# 2           at    Austria                5640             3779           1861
# 3           be    Belgium                4990             3374           1616
# 4           bo    Bolivia                4991             3155           1836
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        3.74                           6.30
# 1                        7.84                          12.12
# 2                        9.03                          14.67
# 3                       10.16                          15.24
# 4                        7.99                          10.99
#
#    Cost Per Month - Premium ($)
# 0                          9.26
# 1                         16.39
# 2                         20.32
# 3                         20.32
# 4                         13.99

# %%
df.tail()
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 60           2075                        5.64                           8.46
# 61           2092                        7.91                          13.20
# 62           1992                        8.99                          13.99
# 63           1835                        8.99                          12.99
# 64           1643                        7.99                          10.99
#
#     Cost Per Month - Premium ($)
# 60                         11.29
# 61                         18.48
# 62                         17.99
# 63                         15.99
# 64                         13.99

# %%
df.describe()
# Out:
#        Total Library Size  No. of TV Shows  No. of Movies  \
# count           65.000000        65.000000      65.000000
# mean          5314.415385      3518.953846    1795.461538
# std            980.322633       723.010556     327.279748
# min           2274.000000      1675.000000     373.000000
# 25%           4948.000000      3154.000000    1628.000000
# 50%           5195.000000      3512.000000    1841.000000
# 75%           5952.000000      3832.000000    1980.000000
# max           7325.000000      5234.000000    2387.000000
#
#        Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# count                   65.000000                      65.000000
# mean                     8.368462                      11.990000
# std                      1.937819                       2.863979
# min                      1.970000                       3.000000
# 25%                      7.990000                      10.710000
# 50%                      8.990000                      11.490000
# 75%                      9.030000                      13.540000
# max                     12.880000                      20.460000
#
#        Cost Per Month - Premium ($)
# count                     65.000000
# mean                      15.612923
# std                        4.040672
# min                        4.020000
# 25%                       13.540000
# 50%                       14.450000
# 75%                       18.060000
# max                       26.960000

# %%
df.columns
# Out:
# Index(['Country_code', 'Country', 'Total Library Size', 'No. of TV Shows',
#        'No. of Movies', 'Cost Per Month - Basic ($)',
#        'Cost Per Month - Standard ($)', 'Cost Per Month - Premium ($)'],
#       dtype='object')

# %%
df.drop(columns=['Country_code'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                          0
# Total Library Size               0
# No. of TV Shows                  0
# No. of Movies                    0
# Cost Per Month - Basic ($)       0
# Cost Per Month - Standard ($)    0
# Cost Per Month - Premium ($)     0
# dtype: int64

# %%
cor=df.corr()
sns.heatmap(cor, xticklabels=cor.columns, yticklabels=cor.columns,annot=True,cmap="BuPu")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
# %matplotlib inline

# %%
most_shows=df.sort_values(by='No. of TV Shows',ascending=False)[:15]
most_shows.reset_index(drop=True,inplace=True)
most_shows
# Out:
#            Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0          Czechia                7325             5234           2091
# 1         Slovakia                7035             5055           1980
# 2         Bulgaria                6797             4819           1978
# 3          Hungary                6884             4802           2082
# 4   United Kingdom                6643             4551           2092
# 5          Ireland                6486             4515           1971
# 6        Lithuania                6462             4490           1972
# 7          Estonia                6456             4486           1970
# 8           Latvia                6450             4479           1971
# 9          Iceland                6387             4426           1961
# 10          Canada                6239             4311           1928
# 11     Philippines                6362             4154           2208
# 12       Singapore                6303             4109           2194
# 13       Gibraltar                6167             4079           2088
# 14       Australia                6114             4050           2064
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                         8.83                          11.49
# 1                         9.03                          11.29
# 2                         9.03                          11.29
# 3                         7.64                          10.71
# 4                         7.91                          13.20
# 5                         9.03                          14.67
# 6                         9.03                          11.29
# 7                         9.03                          11.29
# 8                         9.03                          11.29
# 9                         9.03                          14.67
# 10                        7.91                          11.87
# 11                        7.35                           9.14
# 12                        9.51                          12.81
# 13                        9.03                          14.67
# 14                        7.84                          12.12
#
#     Cost Per Month - Premium ($)
# 0                          14.15
# 1                          13.54
# 2                          13.54
# 3                          13.78
# 4                          18.48
# 5                          20.32
# 6                          13.54
# 7                          13.54
# 8                          13.54
# 9                          20.32
# 10                         15.03
# 11                         10.93
# 12                         16.11
# 13                         20.32
# 14                         16.39

# %%
ax1 = most_shows.plot(x="Country", y="No. of TV Shows", kind="bar", ylabel='No. of TV shows',figsize=(12,8), title='Countries with the most TV Shows', color='red', alpha=0.95 ,edgecolor='black',ylim=(0,6000))
ax1.set_facecolor('#F5F5F5')
ax1.set(xlabel=None)
# Out:
# [Text(0.5, 0, '')]

# %%
least_shows=df.sort_values(by='No. of TV Shows',ascending=True)[:15]
least_shows.reset_index(drop=True,inplace=True)
least_shows
# Out:
#           Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0         Croatia                2274             1675            599
# 1   Liechtenstein                3048             1712           1336
# 2      San Marino                2310             1937            373
# 3       Indonesia                3887             2449           1438
# 4         Moldova                3937             2473           1464
# 5         Finland                4045             2638           1407
# 6       Hong Kong                4746             2883           1863
# 7          Turkey                4639             2930           1709
# 8          Norway                4528             2955           1573
# 9          Sweden                4361             2973           1388
# 10       Thailand                4948             2977           1971
# 11        Denmark                4558             2978           1580
# 12         Taiwan                5105             3134           1971
# 13     Costa Rica                4988             3152           1836
# 14       Honduras                4989             3154           1835
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                         9.03                          11.29
# 1                        12.88                          20.46
# 2                         9.03                          14.67
# 3                         8.36                          10.66
# 4                         9.03                          11.29
# 5                         9.03                          13.54
# 6                         8.08                          10.00
# 7                         1.97                           3.00
# 8                         9.94                          12.17
# 9                        10.90                          14.20
# 10                        8.34                          10.43
# 11                       12.00                          15.04
# 12                        9.74                          11.90
# 13                        8.99                          12.99
# 14                        7.99                          10.99
#
#     Cost Per Month - Premium ($)
# 0                          13.54
# 1                          26.96
# 2                          20.32
# 3                          12.96
# 4                          13.54
# 5                          18.06
# 6                          11.93
# 7                           4.02
# 8                          17.75
# 9                          19.70
# 10                         12.52
# 11                         19.60
# 12                         14.07
# 13                         15.99
# 14                         13.99

# %%
ax2 = least_shows.plot(x="Country", y="No. of TV Shows", kind="bar", ylabel='No. of TV shows',figsize=(12,8), title='Countries with the least TV Shows', color='red', alpha=0.95 ,edgecolor='black',ylim=(0,6000))
ax2.set_facecolor('#F5F5F5')
ax2.set(xlabel=None)
# Out:
# [Text(0.5, 0, '')]

# %%
most_movies=df.sort_values(by='No. of Movies',ascending=False)[:15]
most_movies.reset_index(drop=True,inplace=True)
most_movies
# Out:
#            Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0         Malaysia                5952             3565           2387
# 1      Philippines                6362             4154           2208
# 2        Singapore                6303             4109           2194
# 3            India                5843             3718           2125
# 4   United Kingdom                6643             4551           2092
# 5          Czechia                7325             5234           2091
# 6        Gibraltar                6167             4079           2088
# 7           Russia                5711             3624           2087
# 8          Hungary                6884             4802           2082
# 9      New Zealand                6084             4003           2081
# 10         Ukraine                5336             3261           2075
# 11       Australia                6114             4050           2064
# 12          Israel                5713             3650           2063
# 13    South Africa                5736             3686           2050
# 14          Monaco                5804             3806           1998
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                         8.29                          10.65
# 1                         7.35                           9.14
# 2                         9.51                          12.81
# 3                         2.64                           6.61
# 4                         7.91                          13.20
# 5                         8.83                          11.49
# 6                         9.03                          14.67
# 7                         8.13                          10.84
# 8                         7.64                          10.71
# 9                         8.80                          12.53
# 10                        5.64                           8.46
# 11                        7.84                          12.12
# 12                       10.56                          15.05
# 13                        6.26                          10.05
# 14                        9.03                          13.54
#
#     Cost Per Month - Premium ($)
# 0                          13.02
# 1                          10.93
# 2                          16.11
# 3                           8.60
# 4                          18.48
# 5                          14.15
# 6                          20.32
# 7                          13.56
# 8                          13.78
# 9                          16.94
# 10                         11.29
# 11                         16.39
# 12                         19.54
# 13                         12.58
# 14                         18.06

# %%
ax3 = most_movies.plot(x="Country", y="No. of Movies", kind="bar", ylabel='No. of Movies',figsize=(12,8), title='Countries with the most Movies', color='red', alpha=0.95 ,edgecolor='black',ylim=(0,2600))
ax3.set_facecolor('#F5F5F5')
ax3.set(xlabel=None)
# Out:
# [Text(0.5, 0, '')]

# %%
least_movies=df.sort_values(by='No. of Movies',ascending=True)[:15]
least_movies.reset_index(drop=True,inplace=True)
least_movies
# Out:
#           Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0      San Marino                2310             1937            373
# 1         Croatia                2274             1675            599
# 2   Liechtenstein                3048             1712           1336
# 3          Sweden                4361             2973           1388
# 4         Finland                4045             2638           1407
# 5          Greece                4772             3344           1428
# 6       Indonesia                3887             2449           1438
# 7         Moldova                3937             2473           1464
# 8         Romania                5303             3832           1471
# 9          Norway                4528             2955           1573
# 10        Denmark                4558             2978           1580
# 11    Netherlands                5376             3779           1597
# 12         Poland                5109             3512           1597
# 13      Argentina                4760             3154           1606
# 14      Guatemala                4767             3154           1613
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                         9.03                          14.67
# 1                         9.03                          11.29
# 2                        12.88                          20.46
# 3                        10.90                          14.20
# 4                         9.03                          13.54
# 5                         9.03                          12.42
# 6                         8.36                          10.66
# 7                         9.03                          11.29
# 8                         9.03                          11.29
# 9                         9.94                          12.17
# 10                       12.00                          15.04
# 11                        9.03                          13.54
# 12                        7.13                          10.58
# 13                        3.74                           6.30
# 14                        7.99                          10.99
#
#     Cost Per Month - Premium ($)
# 0                          20.32
# 1                          13.54
# 2                          26.96
# 3                          19.70
# 4                          18.06
# 5                          15.80
# 6                          12.96
# 7                          13.54
# 8                          13.54
# 9                          17.75
# 10                         19.60
# 11                         18.06
# 12                         14.76
# 13                          9.26
# 14                         13.99

# %%
ax4 = least_movies.plot(x="Country", y="No. of Movies", kind="bar", ylabel='No. of Movies',figsize=(12,8), title='Countries with the least Movies', color='red', alpha=0.95 ,edgecolor='black',ylim=(0,2600))
ax4.set_facecolor('#F5F5F5')
ax4.set(xlabel=None)
# Out:
# [Text(0.5, 0, '')]

# %%
least_content=df.sort_values(by='Total Library Size',ascending=True)[:10]
least_content.reset_index(drop=True,inplace=True)
least_content
# Out:
#          Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0        Croatia                2274             1675            599
# 1     San Marino                2310             1937            373
# 2  Liechtenstein                3048             1712           1336
# 3      Indonesia                3887             2449           1438
# 4        Moldova                3937             2473           1464
# 5        Finland                4045             2638           1407
# 6         Sweden                4361             2973           1388
# 7         Norway                4528             2955           1573
# 8        Denmark                4558             2978           1580
# 9         Turkey                4639             2930           1709
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        9.03                          11.29
# 1                        9.03                          14.67
# 2                       12.88                          20.46
# 3                        8.36                          10.66
# 4                        9.03                          11.29
# 5                        9.03                          13.54
# 6                       10.90                          14.20
# 7                        9.94                          12.17
# 8                       12.00                          15.04
# 9                        1.97                           3.00
#
#    Cost Per Month - Premium ($)
# 0                         13.54
# 1                         20.32
# 2                         26.96
# 3                         12.96
# 4                         13.54
# 5                         18.06
# 6                         19.70
# 7                         17.75
# 8                         19.60
# 9                          4.02

# %%
most_content=df.sort_values(by='Total Library Size',ascending=False)[:10]
most_content.reset_index(drop=True,inplace=True)
most_content
# Out:
#           Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0         Czechia                7325             5234           2091
# 1        Slovakia                7035             5055           1980
# 2         Hungary                6884             4802           2082
# 3        Bulgaria                6797             4819           1978
# 4  United Kingdom                6643             4551           2092
# 5         Ireland                6486             4515           1971
# 6       Lithuania                6462             4490           1972
# 7         Estonia                6456             4486           1970
# 8          Latvia                6450             4479           1971
# 9         Iceland                6387             4426           1961
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        8.83                          11.49
# 1                        9.03                          11.29
# 2                        7.64                          10.71
# 3                        9.03                          11.29
# 4                        7.91                          13.20
# 5                        9.03                          14.67
# 6                        9.03                          11.29
# 7                        9.03                          11.29
# 8                        9.03                          11.29
# 9                        9.03                          14.67
#
#    Cost Per Month - Premium ($)
# 0                         14.15
# 1                         13.54
# 2                         13.78
# 3                         13.54
# 4                         18.48
# 5                         20.32
# 6                         13.54
# 7                         13.54
# 8                         13.54
# 9                         20.32

# %%
sns.pairplot(
    data=df,
    y_vars=["Total Library Size"],
    x_vars=["Cost Per Month - Basic ($)", "Cost Per Month - Standard ($)", "Cost Per Month - Premium ($)"],
)

# %%
df
# Out:
#            Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0        Argentina                4760             3154           1606
# 1        Australia                6114             4050           2064
# 2          Austria                5640             3779           1861
# 3          Belgium                4990             3374           1616
# 4          Bolivia                4991             3155           1836
# ..             ...                 ...              ...            ...
# 60         Ukraine                5336             3261           2075
# 61  United Kingdom                6643             4551           2092
# 62   United States                5818             3826           1992
# 63         Uruguay                4989             3154           1835
# 64       Venezuela                4797             3154           1643
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                         3.74                           6.30
# 1                         7.84                          12.12
# 2                         9.03                          14.67
# 3                        10.16                          15.24
# 4                         7.99                          10.99
# ..                         ...                            ...
# 60                        5.64                           8.46
# 61                        7.91                          13.20
# 62                        8.99                          13.99
# 63                        8.99                          12.99
# 64                        7.99                          10.99
#
#     Cost Per Month - Premium ($)
# 0                           9.26
# 1                          16.39
# 2                          20.32
# 3                          20.32
# 4                          13.99
# ..                           ...
# 60                         11.29
# 61                         18.48
# 62                         17.99
# 63                         15.99
# 64                         13.99
#
# [65 rows x 7 columns]

# %%
most_exp=df.sort_values(by=['Cost Per Month - Basic ($)',
       'Cost Per Month - Standard ($)', 'Cost Per Month - Premium ($)'],ascending=False)

pd.set_option('display.max_rows', most_exp.shape[0]+1)
print(most_exp)

# %%
countries=['United Kingdom','India','Singapore','United States','Turkey','Japan','South Korea','France','Switzerland','Norway']
# c=most_exp.set_index('Country')
# cost_graph=c.loc[['United Kingdom','India','Singapore','United States','Turkey','Japan','South Korea']]
# c.loc[countries]
# cost_graph=c.loc[countries]

# cost_graph.reset_index()
# cost_graph.index
cost_graph=most_exp.iloc[[17, 50, 49, 59, 23,2,3,4,43]]
cost_graph
# Out:
#            Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 54           Spain                5229             3536           1693
# 7           Canada                6239             4311           1928
# 61  United Kingdom                6643             4551           2092
# 60         Ukraine                5336             3261           2075
# 6         Bulgaria                6797             4819           1978
# 13         Denmark                4558             2978           1580
# 55          Sweden                4361             2973           1388
# 29          Israel                5713             3650           2063
# 53     South Korea                5195             3334           1861
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 54                        9.03                          14.67
# 7                         7.91                          11.87
# 61                        7.91                          13.20
# 60                        5.64                           8.46
# 6                         9.03                          11.29
# 13                       12.00                          15.04
# 55                       10.90                          14.20
# 29                       10.56                          15.05
# 53                        8.07                          11.47
#
#     Cost Per Month - Premium ($)
# 54                         20.32
# 7                          15.03
# 61                         18.48
# 60                         11.29
# 6                          13.54
# 13                         19.60
# 55                         19.70
# 29                         19.54
# 53                         14.45

# %%
#Calculating the average cost for each subscription

# %%
basic_mean=df['Cost Per Month - Basic ($)'].mean()
basic_mean
# Out:
# 8.368461538461535

# %%
standard_mean=df['Cost Per Month - Standard ($)'].mean()
standard_mean
# Out:
# 11.989999999999998

# %%
premium_mean=df['Cost Per Month - Premium ($)'].mean()
premium_mean
# Out:
# 15.612923076923078

# %%
ax5 = cost_graph.plot(x='Country', y=['Cost Per Month - Basic ($)',
       'Cost Per Month - Standard ($)', 'Cost Per Month - Premium ($)'], kind="bar", ylabel='Cost in $',figsize=(15,10), title='Subscription Price Comparison', color=['#800016','#407ba7','#ff002b'], alpha=0.95 ,width=0.75,edgecolor='black')
ax5.axhline(y=basic_mean, color="#FF9F1C" ,linestyle='dashed', label="Basic Mean in $", linewidth=2.5)
ax5.axhline(y=standard_mean, color="#000000" ,linestyle='solid', label="Standard Mean in $", linewidth=2)
ax5.axhline(y=premium_mean, color="#582F0E" ,linestyle=':', label="Premium Mean in $", linewidth=3)
ax5.legend(loc = 'lower right')

ax5.set_facecolor('#F5F5F5')
ax5.set(xlabel=None)
# Out:
# [Text(0.5, 0, '')]
